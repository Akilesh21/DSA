# %% [markdown]
# PRACTICE

# %%
li = [1,2,3,4,5,6]
li[0]
# Out:
# 1

# %%
li[-1]
l2=[1,2,3,4]
l3 = li + l2
l3*2
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4]

# %%
# Intersections
l1= [int(i) for i in input().split()] 
l2 = [int(j) for j in input().split()]
for i in
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 5
#       3 for i in range(len(l1)):
#       4     for j in range(len(l1)-1):
# ----> 5         if l1[i]==l1[j]:
#       6             l1.pop(i)
#       7             l1.pop(j)
#
# IndexError: list index out of range
