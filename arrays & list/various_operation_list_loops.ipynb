# %%
li = [1,2,3,4,5,"Akhilesh soni","krishna"]
li
# Out:
# [1, 2, 3, 4, 5, 'Akhilesh soni', 'krishna']

# %%
for i in range(len(li)):
    print(li[i])
# Out:
# 1
# 2
# 3
# 4
# 5
# Akhilesh soni
# krishna

# %%
for i in li:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# Akhilesh soni
# krishna
