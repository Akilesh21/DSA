# %%
li = [1,2,3,4,5,6,7,8,9]
li[1]
# Out:
# 2

# %%
li[-3]
# Out:
# 7

# %%
li[1:15]
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
li[17]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\akhil\OneDrive\Desktop\dsa_python\arrays & list\negative_index_list.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/akhil/OneDrive/Desktop/dsa_python/arrays%20%26%20list/negative_index_list.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> li[17]
#
# IndexError: list index out of range

# %%
li[-17]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\akhil\OneDrive\Desktop\dsa_python\arrays & list\negative_index_list.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/akhil/OneDrive/Desktop/dsa_python/arrays%20%26%20list/negative_index_list.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> li[-17]
#
# IndexError: list index out of range

# %%
def sum(arr,n):
    total = 0
    for i in range(len(arr[n:-1])):
        total =total + arr[i+1]
    return total

# %%
li = [1,2,7,8,9,15]
value = sum(li,-9)
value
# Out:
# 41
